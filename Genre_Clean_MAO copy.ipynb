# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Data = pd.read_csv('out/pitchfork_reviews.csv')
Data.head()
# Out:
#              artist              album  score         genre  \
# 0       Jeff Tweedy  Twilight Override    8.0          Rock
# 1             Geese     Getting Killed    9.0          Rock
# 2       Piotr Kurek   Songs and Bodies    7.8  Experimental
# 3  Paul St. Hilaire   w/ the Producers    7.1    Electronic
# 4                 Ø           Sysivalo    8.3    Electronic
#
#                           label          reviewer    year review_date  length  \
# 0                          dBpm  Elizabeth Nelson  2025.0  2025-09-27    1262
# 1  Partisan / Play It Again Sam      Sam Sodomsky  2025.0  2025-09-26     827
# 2                       Unsound  Philip Sherburne  2025.0  2025-09-26     602
# 3             Kynant / N.E.W.S.  Daniel Bromfield  2025.0  2025-09-26     556
# 4                         Sähkö  Philip Sherburne  2025.0  2025-09-25    1170
#
#                                                  url
# 0  https://www.pitchfork.com/reviews/albums/jeff-...
# 1  https://www.pitchfork.com/reviews/albums/geese...
# 2  https://www.pitchfork.com/reviews/albums/piotr...
# 3  https://www.pitchfork.com/reviews/albums/paul-...
# 4  https://www.pitchfork.com/reviews/albums/o-sys...

# %%
Data['genre'].head(20)
# Out:
# 0                                         Rock
# 1                                         Rock
# 2                                 Experimental
# 3                                   Electronic
# 4                                   Electronic
# 5                                   Electronic
# 6                            Electronic / Rock
# 7                                          Rap
# 8                                         Rock
# 9                                         Rock
# 10                                Experimental
# 11    Electronic / Experimental / Folk/Country
# 12                                     Pop/R&B
# 13                                Folk/Country
# 14                                  Electronic
# 15                                  Electronic
# 16                                        Rock
# 17                                        Rock
# 18                                        Rock
# 19                                     Pop/R&B
# Name: genre, dtype: object

# %%
Data['genre'].unique()
# Out:
# array(['Rock', 'Experimental', 'Electronic', 'Electronic / Rock', 'Rap',
#        'Electronic / Experimental / Folk/Country', 'Pop/R&B',
#        'Folk/Country', 'Pop/R&B / Electronic / Rap', 'Jazz',
#        'Pop/R&B / Rock', 'Metal', 'Electronic / Pop/R&B',
#        'Jazz / Rock / Experimental', 'Metal / Rock', 'Pop/R&B / Jazz',
#        'Which?', 'Folk/Country / Rock', 'Rap / Rock',
#        'Rock / Experimental', 'Experimental / Pop/R&B', 'Rap / Pop/R&B',
#        'Rap / Experimental', 'Electronic / Experimental',
#        'Electronic / Rap', 'Experimental / Electronic',
#        'Electronic / Rock / Experimental', '+ambién',
#        'Folk/Country / Pop/R&B', 'Rock / Electronic / Folk/Country',
#        'Rap / Electronic', 'Electronic / Experimental / Jazz',
#        'Pop/R&B / Electronic', 'Jazz / Experimental',
#        'Experimental / Rap', 'Rock / Electronic',
#        'Experimental / Folk/Country', 'Rock / Experimental / Jazz',
#        'Experimental / Rock', 'Rock / Pop/R&B', 'Experimental / Jazz',
#        'Folk/Country / Jazz', 'Electronic / Experimental / Rock',
#        'Experimental / Metal / Rock', 'Electronic / Folk/Country',
#        'Pop/R&B / Rap', 'Reprise / Southern', 'Rock / Folk/Country',
#        'Jazz / Pop/R&B / Rap', 'Experimental / Pop/R&B / Folk/Country',
#        'Folk/Country / Experimental', 'Pop/R&B / Experimental', 'topo2',
#        'Naya Beat', 'Music From Memory',
#        'Electronic / Experimental / Metal', 'Light in the Attic',
#        'forms of minutiae', 'Jazz / Pop/R&B', 'American Dreams', 'Rawkus',
#        'Folk/Country / Rap / Pop/R&B', 'Rock / Metal',
#        'Electronic / Jazz / Rock', 'Electronic / Jazz',
#        'Pop/R&B / Experimental / Rock', 'Strut',
#        'Rap / Electronic / Rock', 'Rvng Intl.', 'Folk/Country / Rap',
#        'A24 Music', 'Pop/R&B / Folk/Country', 'NTS', 'Rock / Jazz',
#        'Electronic / Experimental / Rap', 'Other People / Unsound',
#        'Time Capsule', 'Experimental / Jazz / Rock', 'Mappa Editions',
#        'Experimental / Pop/R&B / Electronic',
#        'Electronic / Experimental / Pop/R&B', 'The state51 Conspiracy',
#        'PC Music', 'Atlantic', 'Folk/Country / Jazz / Pop/R&B',
#        'Jazz / Electronic', 'Jazz / Rap', 'Pop/R&B / Rap / Electronic',
#        'Experimental / Folk/Country / Rock',
#        'Folk/Country / Global / Pop/R&B', 'Anthology', 'Craft',
#        'Jazz / Rock', 'Folk/Country / Pop/R&B / Rock',
#        'Experimental / Electronic / Pop/R&B', 'Smithsonian Folkways',
#        'Jazz / Experimental / Folk/Country', 'Razor & Tie / Universal',
#        'Wisdom Teeth', 'Missing Piece',
#        'Roc Nation / Def Jam / Hollywood',
#        'Rock / Pop/R&B / Folk/Country', 'Metal / Rock / Experimental',
#        'Total Punk', 'Jalopy', 'Numero Group', 'Anti- / Epitaph',
#        'Folk/Country / Electronic', 'Metal / Experimental', 'Decca',
#        'UMG / Sony Music Entertainment', 'Joyful Noise',
#        'Experimental / Rap / Electronic', 'Nyege Nyege Tapes', 'Leaving',
#        'You’ve Changed', 'May 2, 2022',
#        'Experimental / Electronic / Rock', 'Rock Action', 'To3s',
#        'Pure Noise', 'Bilna’es', 'Last Gang', 'Global / Pop/R&B', 'Avian',
#        'Rap / Pop/R&B / Electronic', 'Thesis & Instinct', 'Erased Tapes',
#        'Republic', 'Cherry Red', 'Yellow Electric', 'Legacy',
#        'Paper Route Empire', 'Jazz / Global / Rock', 'Global / Jazz',
#        'Jazz / Pop/R&B / Rock', 'MOVES', 'Oh Boy', 'Global',
#        'Jazz / Metal', 'Wewantsounds', 'Livity Sound', 'Sumerian',
#        'Verve', 'ITALIANS DO IT BETTER', 'Global / Rock',
#        'Republic / Warner Bros.', 'June 2, 2021', 'Doom Trip',
#        'Rock / Rap', 'Agva', '4AD', 'BBE Music', 'RCA', 'Rock Is Hell',
#        'Griselda', 'Folk/Country / Rock / Pop/R&B', 'Planet Mu',
#        'Captured Tracks', 'Idée Fixe', 'Mercury', 'Electronic / Metal',
#        'Rap / Jazz', 'More Rice', 'BMG', 'Electronic / Global',
#        'Castle Face', 'Electronic / Global / Rock', 'self-released',
#        'Year0001', 'Rap / Folk/Country / Pop/R&B / Rock', 'Bando',
#        'Virgin', 'Jazz / Rock / Pop/R&B / Rap', 'Dekmantel',
#        'CMNTY CULTURE / Warner', 'Spring Theory', 'Hardly Art',
#        'Mineral Disk', 'Whities', "Mother's Finest", 'Kulør', 'Relapse',
#        'Shall Not Fade', 'Analog Africa', 'Don Giovanni', 'Warner',
#        'Fabric', 'Hyperdub / Adult Swim', 'Motown', 'R&S',
#        'SCI-FI & FANTASY', 'Warp', 'VP', 'Dais', 'The Flenser',
#        'Metal / Rap', 'Jazz / Experimental / Rock',
#        'Experimental / Metal', 'Third Man', 'Factory', 'Tiny Engines',
#        'Luaka Bop', 'Oramics', 'Quality Control', 'Fool’s Gold', 'Mute',
#        'Columbia / Legacy', 'Peak Oil', 'Rhino', 'Columbia', 'Sony',
#        'Counter Intuitive', 'Dreamville / Interscope',
#        'Big Hit Entertainment', 'Infiné', 'Python Syndicate',
#        'Global / Pop/R&B / Rap', 'Interscope', 'OAR', 'Goner',
#        'Southern Lord', 'Infinite Companion', 'Columbia / HBO',
#        'Electronic / Jazz / Pop/R&B', 'Wax Trax!', 'Carpark', 'Waxwork',
#        'L.I.E.S.', 'All City', 'Beats in Space', 'трип', 'Kompakt', 'ECM',
#        'Sub Pop', 'Pop/R&B / Global', 'Studio Barnhus', 'Moog Records',
#        'Bella Union', '88rising', 'Experimental / Global',
#        'Rap / Folk/Country / Pop/R&B', 'Loma Vista', 'Timedance',
#        'Where to Now?', 'Experimental / Rap / Rock', 'Bronson',
#        'Beyond The Groove', 'NON Worldwide', 'ABKCO',
#        'Allergy Season / Discwoman', 'Rush Hour', 'Drag City',
#        'Top Dawg Entertainment / Aftermath / Interscope', 'Hyperdub',
#        'Habibi Funk Records', 'Mood Hut',
#        'Madison Gate / Sony Music Masterworks', 'Eskimo',
#        "What's Your Rupture? / R.I.P. Society", 'Black Editions', 'Mondo',
#        'Shanachie', 'Music For Dreams', 'Emotional Rescue', 'Soul Jazz',
#        'Hostel La Torre', 'First Terrace', 'Topshelf', 'Profound Lore',
#        'Jazz / Global', 'Folk/Country / Electronic / Experimental',
#        'Antinote', 'Jazz / Pop/R&B / Global', 'Umor Rex', 'Sony / Legacy',
#        'Owsla', 'Optimo Music', 'April 5, 2017', 'Pan',
#        'Rush Hour / Prescription'], dtype=object)

# %%
Data2 = Data.copy()  # keep original safe

Data2['genre_clean'] = (
    Data2['genre']
    .astype(str) # make sure it's a string
    .str.replace('⁄', '/', regex=False)  # in case some rows use a weird slash
    .str.strip() # remove spaces at start/end
)

Data2[['genre', 'genre_clean']].head(20)
# Out:
#                                        genre  \
# 0                                       Rock
# 1                                       Rock
# 2                               Experimental
# 3                                 Electronic
# 4                                 Electronic
# 5                                 Electronic
# 6                          Electronic / Rock
# 7                                        Rap
# 8                                       Rock
# 9                                       Rock
# 10                              Experimental
# 11  Electronic / Experimental / Folk/Country
# 12                                   Pop/R&B
# 13                              Folk/Country
# 14                                Electronic
# 15                                Electronic
# 16                                      Rock
# 17                                      Rock
# 18                                      Rock
# 19                                   Pop/R&B
#
#                                  genre_clean
# 0                                       Rock
# 1                                       Rock
# 2                               Experimental
# 3                                 Electronic
# 4                                 Electronic
# 5                                 Electronic
# 6                          Electronic / Rock
# 7                                        Rap
# 8                                       Rock
# 9                                       Rock
# 10                              Experimental
# 11  Electronic / Experimental / Folk/Country
# 12                                   Pop/R&B
# 13                              Folk/Country
# 14                                Electronic
# 15                                Electronic
# 16                                      Rock
# 17                                      Rock
# 18                                      Rock
# 19                                   Pop/R&B

# %%
Data2['genre_clean'] = Data2['genre_clean'].replace({
    'Pop/R&B': 'Pop_R&B',
    'Folk/Country': 'Folk_Country'
})

# %%
Data2['genre_list'] = Data2['genre_clean'].apply(
    lambda x: [p.strip() for p in x.split('/') if p.strip() != ""]
) # take every value in genre_clean, split on /, trim spaces, ignore empty pieces, store the result in a new column called genre_list

Data2[['genre_clean', 'genre_list']].head(25)
# Out:
#                                  genre_clean  \
# 0                                       Rock
# 1                                       Rock
# 2                               Experimental
# 3                                 Electronic
# 4                                 Electronic
# 5                                 Electronic
# 6                          Electronic / Rock
# 7                                        Rap
# 8                                       Rock
# 9                                       Rock
# 10                              Experimental
# 11  Electronic / Experimental / Folk/Country
# 12                                   Pop_R&B
# 13                              Folk_Country
# 14                                Electronic
# 15                                Electronic
# 16                                      Rock
# 17                                      Rock
# 18                                      Rock
# 19                                   Pop_R&B
# 20                Pop/R&B / Electronic / Rap
# 21                                   Pop_R&B
# 22                                      Rock
# 23                                   Pop_R&B
# 24                                      Rock
#
#                                    genre_list
# 0                                      [Rock]
# 1                                      [Rock]
# 2                              [Experimental]
# 3                                [Electronic]
# 4                                [Electronic]
# 5                                [Electronic]
# 6                          [Electronic, Rock]
# 7                                       [Rap]
# 8                                      [Rock]
# 9                                      [Rock]
# 10                             [Experimental]
# 11  [Electronic, Experimental, Folk, Country]
# 12                                  [Pop_R&B]
# 13                             [Folk_Country]
# 14                               [Electronic]
# 15                               [Electronic]
# 16                                     [Rock]
# 17                                     [Rock]
# 18                                     [Rock]
# 19                                  [Pop_R&B]
# 20                [Pop, R&B, Electronic, Rap]
# 21                                  [Pop_R&B]
# 22                                     [Rock]
# 23                                  [Pop_R&B]
# 24                                     [Rock]

# %%
valid_genres = {
    'rock': 'Rock',
    'electronic': 'Electronic',
    'experimental': 'Experimental',
    'rap': 'Rap',
    'pop_r&b': 'Pop/R&B',       # remember: underscore version
    'folk_country': 'Folk/Country',
    'jazz': 'Jazz',
    'metal': 'Metal',
    'global': 'Global'
}

# Goes through each list and keep only the ones in valid_genres
def keep_only_real_genres(parts):
    kept = []
    for p in parts:
        key = p.lower()
        if key in valid_genres:
            kept.append(valid_genres[key])   # store the nice version
    # remove duplicates but keep order
    return list(dict.fromkeys(kept))

Data2['genre_cleaned'] = Data2['genre_list'].apply(keep_only_real_genres)
Data2[['genre', 'genre_list', 'genre_cleaned']].head(30)
# Out:
#                                        genre  \
# 0                                       Rock
# 1                                       Rock
# 2                               Experimental
# 3                                 Electronic
# 4                                 Electronic
# 5                                 Electronic
# 6                          Electronic / Rock
# 7                                        Rap
# 8                                       Rock
# 9                                       Rock
# 10                              Experimental
# 11  Electronic / Experimental / Folk/Country
# 12                                   Pop/R&B
# 13                              Folk/Country
# 14                                Electronic
# 15                                Electronic
# 16                                      Rock
# 17                                      Rock
# 18                                      Rock
# 19                                   Pop/R&B
# 20                Pop/R&B / Electronic / Rap
# 21                                   Pop/R&B
# 22                                      Rock
# 23                                   Pop/R&B
# 24                                      Rock
# 25                                      Rock
# 26                                      Rock
# 27                                Electronic
# 28                                       Rap
# 29                                      Rock
#
#                                    genre_list               genre_cleaned
# 0                                      [Rock]                      [Rock]
# 1                                      [Rock]                      [Rock]
# 2                              [Experimental]              [Experimental]
# 3                                [Electronic]                [Electronic]
# 4                                [Electronic]                [Electronic]
# 5                                [Electronic]                [Electronic]
# 6                          [Electronic, Rock]          [Electronic, Rock]
# 7                                       [Rap]                       [Rap]
# 8                                      [Rock]                      [Rock]
# 9                                      [Rock]                      [Rock]
# 10                             [Experimental]              [Experimental]
# 11  [Electronic, Experimental, Folk, Country]  [Electronic, Experimental]
# 12                                  [Pop_R&B]                   [Pop/R&B]
# 13                             [Folk_Country]              [Folk/Country]
# 14                               [Electronic]                [Electronic]
# 15                               [Electronic]                [Electronic]
# 16                                     [Rock]                      [Rock]
# 17                                     [Rock]                      [Rock]
# 18                                     [Rock]                      [Rock]
# 19                                  [Pop_R&B]                   [Pop/R&B]
# 20                [Pop, R&B, Electronic, Rap]           [Electronic, Rap]
# 21                                  [Pop_R&B]                   [Pop/R&B]
# 22                                     [Rock]                      [Rock]
# 23                                  [Pop_R&B]                   [Pop/R&B]
# 24                                     [Rock]                      [Rock]
# 25                                     [Rock]                      [Rock]
# 26                                     [Rock]                      [Rock]
# 27                               [Electronic]                [Electronic]
# 28                                      [Rap]                       [Rap]
# 29                                     [Rock]                      [Rock]

# %%
Data2['genre_clean'] = (
    Data2['genre']
    .astype(str)
    .str.replace('⁄', '/', regex=False)
    .str.strip()
)

Data2['genre_clean'] = (
    Data2['genre_clean']
    .str.replace('Folk/Country', 'Folk_Country', regex=False)
    .str.replace('Pop/R&B', 'Pop_R&B', regex=False)
)

Data2['genre_list'] = Data2['genre_clean'].apply(
    lambda x: [p.strip() for p in x.split('/') if p.strip() != ""]
)

valid_genres = {
    'rock': 'Rock',
    'electronic': 'Electronic',
    'experimental': 'Experimental',
    'rap': 'Rap',
    'pop_r&b': 'Pop/R&B',
    'folk_country': 'Folk/Country',
    'jazz': 'Jazz',
    'metal': 'Metal',
    'global': 'Global'
}

def keep_only_real_genres(parts):
    kept = []
    for p in parts:
        key = p.lower()
        if key in valid_genres:
            kept.append(valid_genres[key])
    return list(dict.fromkeys(kept))

Data2['genre_cleaned'] = Data2['genre_list'].apply(keep_only_real_genres)

Data2[['genre', 'genre_list', 'genre_cleaned']].head(30)
# Out:
#                                        genre  \
# 0                                       Rock
# 1                                       Rock
# 2                               Experimental
# 3                                 Electronic
# 4                                 Electronic
# 5                                 Electronic
# 6                          Electronic / Rock
# 7                                        Rap
# 8                                       Rock
# 9                                       Rock
# 10                              Experimental
# 11  Electronic / Experimental / Folk/Country
# 12                                   Pop/R&B
# 13                              Folk/Country
# 14                                Electronic
# 15                                Electronic
# 16                                      Rock
# 17                                      Rock
# 18                                      Rock
# 19                                   Pop/R&B
# 20                Pop/R&B / Electronic / Rap
# 21                                   Pop/R&B
# 22                                      Rock
# 23                                   Pop/R&B
# 24                                      Rock
# 25                                      Rock
# 26                                      Rock
# 27                                Electronic
# 28                                       Rap
# 29                                      Rock
#
#                                   genre_list  \
# 0                                     [Rock]
# 1                                     [Rock]
# 2                             [Experimental]
# 3                               [Electronic]
# 4                               [Electronic]
# 5                               [Electronic]
# 6                         [Electronic, Rock]
# 7                                      [Rap]
# 8                                     [Rock]
# 9                                     [Rock]
# 10                            [Experimental]
# 11  [Electronic, Experimental, Folk_Country]
# 12                                 [Pop_R&B]
# 13                            [Folk_Country]
# 14                              [Electronic]
# 15                              [Electronic]
# 16                                    [Rock]
# 17                                    [Rock]
# 18                                    [Rock]
# 19                                 [Pop_R&B]
# 20                [Pop_R&B, Electronic, Rap]
# 21                                 [Pop_R&B]
# 22                                    [Rock]
# 23                                 [Pop_R&B]
# 24                                    [Rock]
# 25                                    [Rock]
# 26                                    [Rock]
# 27                              [Electronic]
# 28                                     [Rap]
# 29                                    [Rock]
#
#                                genre_cleaned
# 0                                     [Rock]
# 1                                     [Rock]
# 2                             [Experimental]
# 3                               [Electronic]
# 4                               [Electronic]
# 5                               [Electronic]
# 6                         [Electronic, Rock]
# 7                                      [Rap]
# 8                                     [Rock]
# 9                                     [Rock]
# 10                            [Experimental]
# 11  [Electronic, Experimental, Folk/Country]
# 12                                 [Pop/R&B]
# 13                            [Folk/Country]
# 14                              [Electronic]
# 15                              [Electronic]
# 16                                    [Rock]
# 17                                    [Rock]
# 18                                    [Rock]
# 19                                 [Pop/R&B]
# 20                [Pop/R&B, Electronic, Rap]
# 21                                 [Pop/R&B]
# 22                                    [Rock]
# 23                                 [Pop/R&B]
# 24                                    [Rock]
# 25                                    [Rock]
# 26                                    [Rock]
# 27                              [Electronic]
# 28                                     [Rap]
# 29                                    [Rock]

# %%
all_genres = set()

for lst in Data2['genre_cleaned']:
    for g in lst:
        all_genres.add(g)

sorted(all_genres)
# Out:
# ['Electronic',
#  'Experimental',
#  'Folk/Country',
#  'Global',
#  'Jazz',
#  'Metal',
#  'Pop/R&B',
#  'Rap',
#  'Rock']

# %%
Data2['genre_len'] = Data2['genre_cleaned'].apply(len)
Data2['genre_len'].value_counts()
# Out:
# genre_len
# 1    7834
# 2     798
# 0     210
# 3      82
# 4       2
# Name: count, dtype: int64

# %%
Data2[Data2['genre_len'] == 0][['genre']].head(50)
# Out:
#                                  genre
# 97                              Which?
# 216                           +ambién
# 518                 Reprise / Southern
# 669                              topo2
# 688                          Naya Beat
# 728                  Music From Memory
# 745                 Light in the Attic
# 770                  forms of minutiae
# 810                    American Dreams
# 865                             Rawkus
# 910                              Strut
# 1022                        Rvng Intl.
# 1072                         A24 Music
# 1166                               NTS
# 1354            Other People / Unsound
# 1380                      Time Capsule
# 1410                    Mappa Editions
# 1545            The state51 Conspiracy
# 1679                          PC Music
# 1751                          Atlantic
# 1943                          PC Music
# 2101                         Anthology
# 2129                             Craft
# 2206              Smithsonian Folkways
# 2256           Razor & Tie / Universal
# 2286                      Wisdom Teeth
# 2363                     Missing Piece
# 2383  Roc Nation / Def Jam / Hollywood
# 2552                        Total Punk
# 2659                            Jalopy
# 2661                      Numero Group
# 2665                   Anti- / Epitaph
# 2763                Light in the Attic
# 2793                             Decca
# 2841    UMG / Sony Music Entertainment
# 2843                      Joyful Noise
# 2929                         Anthology
# 2944                          PC Music
# 2946                 Nyege Nyege Tapes
# 2954                           Leaving
# 2966                    You’ve Changed
# 2994                       May 2, 2022
# 3006                       Rock Action
# 3010                              To3s
# 3012                        Pure Noise
# 3079                          Bilna’es
# 3095                         Last Gang
# 3118            Other People / Unsound
# 3122                             Avian
# 3178                          Atlantic

# %%
mask = Data2['genre_len'] == 0
# Replace with ['Unknown'] so the column stays a list
Data2.loc[mask, 'genre_cleaned'] = [['Unknown']] * mask.sum()

# %%
Data2.loc[mask, ['genre', 'genre_cleaned']].head(10)
# See how many 'Unknown' we have now
Data2['genre_cleaned'].value_counts().head(10)
# Out:
# genre_cleaned
# [Rock]                        2676
# [Rap]                         1406
# [Electronic]                  1141
# [Pop/R&B]                     1033
# [Experimental]                 735
# [Folk/Country]                 400
# [Jazz]                         241
# Unknown                        210
# [Metal]                        182
# [Electronic, Experimental]      81
# Name: count, dtype: int64

# %%
def ensure_list(x):
    if isinstance(x, list):
        return x
    elif pd.isna(x):
        return []
    else:
        return [x]

Data2['genre_cleaned'] = Data2['genre_cleaned'].apply(ensure_list)
Data2['genre_cleaned'].value_counts().head(10)
# Out:
# genre_cleaned
# [Rock]                        2676
# [Rap]                         1406
# [Electronic]                  1141
# [Pop/R&B]                     1033
# [Experimental]                 735
# [Folk/Country]                 400
# [Jazz]                         241
# [Unknown]                      210
# [Metal]                        182
# [Electronic, Experimental]      81
# Name: count, dtype: int64

# %%
def get_main_genre(val):
    if isinstance(val, list):
        if len(val) == 0:
            return 'Unknown'
        else:
            return val[0]   # take the first genre
    elif isinstance(val, str):
        return val
    else:
        return 'Unknown'

Data2['main_genre'] = Data2['genre_cleaned'].apply(get_main_genre)
Data2['main_genre'].value_counts()
# Out:
# main_genre
# Rock            2781
# Rap             1471
# Electronic      1387
# Pop/R&B         1162
# Experimental     909
# Folk/Country     462
# Jazz             309
# Unknown          210
# Metal            203
# Global            32
# Name: count, dtype: int64

# %% [markdown]
# I cleaned the genre column by fixing formatting, removing label-only values, standardizing real genres, replacing invalid cases with ‘Unknown,’ and creating a main_genre column based on the first genre originally listed for each album.

# %%
Data2[['artist', 'album', 'genre', 'genre_cleaned', 'main_genre']].sample(10, random_state=42)
# Out:
#                       artist             album                        genre  \
# 6170         Together Pangea  Dispassionate EP                         Rock
# 5832             Terry Riley         Sun Rings                 Experimental
# 286                    Smerz     Big city life                      Pop/R&B
# 8484       Portugal. The Man         Woodstock                         Rock
# 5684          Sufjan Stevens     The Decalogue  Folk/Country / Experimental
# 761             Leon Bridges              Leon                      Pop/R&B
# 3684              Nite Jewel            No Sun                      Pop/R&B
# 7879  Francis and the Lights       Just for Us                      Pop/R&B
# 1421          Frost Children       Hearth Room                   Electronic
# 1543                   Drake  For All the Dogs                          Rap
#
#                      genre_cleaned    main_genre
# 6170                        [Rock]          Rock
# 5832                [Experimental]  Experimental
# 286                      [Pop/R&B]       Pop/R&B
# 8484                        [Rock]          Rock
# 5684  [Folk/Country, Experimental]  Folk/Country
# 761                      [Pop/R&B]       Pop/R&B
# 3684                     [Pop/R&B]       Pop/R&B
# 7879                     [Pop/R&B]       Pop/R&B
# 1421                  [Electronic]    Electronic
# 1543                         [Rap]           Rap

# %%
Data2['main_genre'].value_counts()
# Out:
# main_genre
# Rock            2781
# Rap             1471
# Electronic      1387
# Pop/R&B         1162
# Experimental     909
# Folk/Country     462
# Jazz             309
# Unknown          210
# Metal            203
# Global            32
# Name: count, dtype: int64

# %%
Data2.to_csv('out/pitchfork_reviews_clean_MAO.csv', index=False)
