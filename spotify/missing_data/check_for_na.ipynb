# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/Users/heywood/Desktop/ds6021-pitchfork/spotify/artist_followers.csv')
# Display the first few rows of the dataframe
df.head()

# Check for missing values in the dataframe
missing_values = df.isna().sum()
print(missing_values)
# Out:
# artist_id          0
# followers_count    0
# dtype: int64
